# %%
with open('problem1_input.txt') as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['3264\n',
#  '4043\n',
#  '2537\n',
#  '3319\n',
#  '2485\n',
#  '3218\n',
#  '5611\n',
#  '1753\n',
#  '7232\n',
#  '3265\n',
#  '1751\n',
#  '2233\n',
#  '\n',
#  '10589\n',
#  '5121\n',
#  '11465\n',
#  '9307\n',
#  '1347\n',
#  '9392\n',
#  '12037\n',
#  '\n',
#  '6025\n',
#  '4328\n',
#  '3982\n',
#  '4487\n',
#  '1139\n',
#  '1440\n',
#  '2970\n',
#  '3390\n',
#  '1844\n',
#  '5400\n',
#  '1651\n',
#  '4109\n',
#  '3584\n',
#  '2926\n',
#  '4297\n',
#  '\n',
#  '8921\n',
#  '13298\n',
#  '12300\n',
#  '5607\n',
#  '3304\n',
#  '5037\n',
#  '\n',
#  '1729\n',
#  '10057\n',
#  '\n',
#  '3538\n',
#  '3984\n',
#  '3451\n',
#  '5638\n',
#  '2880\n',
#  '1008\n',
#  '2940\n',
#  '6245\n',
#  '3865\n',
#  '5060\n',
#  '2878\n',
#  '2460\n',
#  '6557\n',
#  '\n',
#  '1584\n',
#  '6391\n',
#  '3479\n',
#  '2264\n',
#  '2683\n',
#  '3680\n',
#  '1183\n',
#  '5121\n',
#  '6499\n',
#  '5543\n',
#  '1192\n',
#  '4818\n',
#  '\n',
#  '1337\n',
#  '8128\n',
#  '8966\n',
#  '7601\n',
# ...

# %%
elf_cal_list = []

# %%
cal_per_elf=0
for i in lines:
    
#     while (i != '\n'):
#         cal_per_elf += int(i.strip())
#     elf_cal_list.append(cal_per_elf)
    if (i != '\n'):
        cal_per_elf += int(i.strip())
    else:
        elf_cal_list.append(cal_per_elf)
        cal_per_elf = 0

# %%
elf_cal_list
# Out:
# [40711,
#  59258,
#  51572,
#  48467,
#  11786,
#  50504,
#  44437,
#  49218,
#  49780,
#  42837,
#  27353,
#  59114,
#  48165,
#  40691,
#  61534,
#  54445,
#  38633,
#  29052,
#  53200,
#  46210,
#  45702,
#  41934,
#  51441,
#  9262,
#  37106,
#  41269,
#  7273,
#  47406,
#  39256,
#  48368,
#  37360,
#  48577,
#  30999,
#  69149,
#  49088,
#  46640,
#  40563,
#  3007,
#  42988,
#  72070,
#  42948,
#  32759,
#  40351,
#  57039,
#  41144,
#  45598,
#  54880,
#  62734,
#  61833,
#  60791,
#  60822,
#  48318,
#  46253,
#  50971,
#  21381,
#  51040,
#  3366,
#  40526,
#  56909,
#  49894,
#  50057,
#  27897,
#  45535,
#  51499,
#  59124,
#  58856,
#  52990,
#  49112,
#  36811,
#  53476,
#  46802,
#  57042,
#  53196,
#  43208,
#  43935,
#  55285,
#  36426,
#  48199,
#  21305,
#  62492,
#  58542,
#  57526,
#  44093,
#  38949,
#  38541,
#  51914,
#  55735,
#  52827,
#  50659,
#  34597,
#  58167,
#  39794,
#  43493,
#  51291,
#  43998,
#  39488,
#  62189,
#  15736,
#  39610,
#  45464,
# ...

# %%
curmax = elf_cal_list[0]

# %%
idx=0
for i in range(0, len(elf_cal_list)):
    if elf_cal_list[i]>curmax:
        curmax = elf_cal_list[i]
        idx = i

# %%
idx
# Out:
# 39

# %%
elf_cal_list[39]
# Out:
# 72070

# %%
elf_cal_list_sorted = elf_cal_list.sort()

# %%
elf_cal_list.sort(reverse=True)

# %%
elf_cal_list
# Out:
# [72070,
#  70586,
#  69149,
#  68282,
#  68092,
#  67167,
#  66341,
#  66287,
#  65678,
#  64743,
#  62734,
#  62492,
#  62407,
#  62264,
#  62189,
#  61833,
#  61737,
#  61718,
#  61534,
#  61434,
#  60822,
#  60791,
#  60534,
#  60270,
#  60207,
#  60201,
#  59502,
#  59488,
#  59258,
#  59221,
#  59124,
#  59114,
#  58856,
#  58542,
#  58468,
#  58448,
#  58370,
#  58260,
#  58167,
#  58010,
#  57856,
#  57526,
#  57334,
#  57203,
#  57042,
#  57039,
#  56909,
#  56813,
#  56576,
#  56196,
#  56035,
#  55926,
#  55848,
#  55846,
#  55735,
#  55472,
#  55427,
#  55285,
#  55275,
#  54998,
#  54880,
#  54829,
#  54583,
#  54445,
#  54404,
#  54193,
#  54106,
#  54064,
#  53979,
#  53968,
#  53596,
#  53476,
#  53200,
#  53196,
#  52990,
#  52827,
#  52815,
#  52762,
#  52565,
#  52479,
#  52401,
#  52224,
#  52101,
#  52095,
#  52090,
#  51946,
#  51914,
#  51751,
#  51572,
#  51499,
#  51445,
#  51441,
#  51339,
#  51291,
#  51280,
#  51040,
#  51009,
#  50971,
#  50659,
#  50504,
# ...

# %%
total = elf_cal_list[0] + elf_cal_list[1]  + elf_cal_list[2]

# %%
total
# Out:
# 211805
