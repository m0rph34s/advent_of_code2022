# %% [markdown]
# ## Because elves don't understand line breaks

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
with open('problem6_input.txt') as f:
    signal = f.read()

# %%
signal
# Out:
# '...'

# %%
print(len(signal))
# Out:
# 4095

# %%
candidate_character = ''

# %%
for i in range(len(signal)-3):
    candidate_character = signal[i:i+4]
    if (len(set(candidate_character)) == 4):
        print (i+4)
        break
# Out:
# 1833

# %%
a= 'asdfjkla'

len(set(a))==len(a)
# Out:
# False

# %%
candidate_character=''
for i in range(len(signal)-13):
    candidate_character = signal[i:i+14]
    if (len(set(candidate_character)) == 14):
        print (i+14)
        break
# Out:
# 3425
